# %% [markdown]
# <a href="https://colab.research.google.com/github/darshilnagle7-create/pandas-assignments/blob/main/Pandas_class3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Class 3: Data Cleaning Essentials
# Welcome to **Class 3** of our Pandas series. Today we’ll learn how to clean and prepare data for analysis.

# %% [markdown]
# ## Handling Missing Values
# Real-world datasets often have missing data. Pandas offers:
# - `isna()` / `isnull()` → detect missing values (returns True/False)
# - `dropna()` → remove missing values (rows/columns)
# - `fillna()` → replace missing values with a given value or method (e.g., forward fill)
#
# Always inspect how much data is missing before deciding to drop or fill.

# %%
import pandas as pd
import numpy as np
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, None, 35, 40, None],
    "City": ["Delhi", "Mumbai", None, "Bangalore", "Chennai"],
    "Score": [85, 91, np.nan, 88, 95]
}

b = pd.DataFrame(a)
print(b)

#1. .isna() -> null values -> marks by True.
print(b.isna())

#2. .isnull() -> Null values.
print(b.isnull())
print(b.isnull().sum()) # column wise null values count.
# Out:
#       Name   Age       City  Score
# 0    Alice  25.0      Delhi   85.0
# 1      Bob   NaN     Mumbai   91.0
# 2  Charlie  35.0       None    NaN
# 3    David  40.0  Bangalore   88.0
# 4     Emma   NaN    Chennai   95.0
#     Name    Age   City  Score
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True   True
# 3  False  False  False  False
# 4  False   True  False  False
#     Name    Age   City  Score
# 0  False  False  False  False
# 1  False   True  False  False
# 2  False  False   True   True
# 3  False  False  False  False
# 4  False   True  False  False
# Name     0
# Age      2
# City     1
# Score    1
# dtype: int64

# %%
print(b)

print(b.dropna()) # ->Remove the rows where null values are present

#filling null values of age columns.
b['Age'].fillna(b['Age'].mean(),inplace = True)

#Filling by value 0
b['Score'].fillna(0,inplace=True)

#Filling by placeholder ("Unknown")
b['City'].fillna("Unknown",inplace=True)
print(b)
# Out:
#       Name        Age       City  Score
# 0    Alice  25.000000      Delhi   85.0
# 1      Bob  33.333333     Mumbai   91.0
# 2  Charlie  35.000000       None    0.0
# 3    David  40.000000  Bangalore   88.0
# 4     Emma  33.333333    Chennai   95.0
#     Name        Age       City  Score
# 0  Alice  25.000000      Delhi   85.0
# 1    Bob  33.333333     Mumbai   91.0
# 3  David  40.000000  Bangalore   88.0
# 4   Emma  33.333333    Chennai   95.0
#       Name        Age       City  Score
# 0    Alice  25.000000      Delhi   85.0
# 1      Bob  33.333333     Mumbai   91.0
# 2  Charlie  35.000000    Unknown    0.0
# 3    David  40.000000  Bangalore   88.0
# 4     Emma  33.333333    Chennai   95.0
# /tmp/ipykernel_5760/2008677250.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Age'].fillna(b['Age'].mean(),inplace = True)
# /tmp/ipykernel_5760/2008677250.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Score'].fillna(0,inplace=True)
# /tmp/ipykernel_5760/2008677250.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['City'].fillna("Unknown",inplace=True)

# %% [markdown]
# ## Changing Data Types (`astype`)
# - Convert a column to a different type using `astype()`.
# - Examples: converting strings to numbers, integers to floats, or columns to category.
#
# Be careful: make sure the data is compatible with the new type!

# %%
a = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 35, 40, 22],
    "Score": [88, 92, 79, 85, 95]
}

b = pd.DataFrame(a)

#astype() -> For data type conversion.
b['Age'].astype(float)
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    40.0
# 4    22.0
# Name: Age, dtype: float64

# %% [markdown]
# ## Replacing Values (`replace`)
# - Use `replace()` to substitute specific values or patterns.
# - Useful for cleaning labels, fixing typos, or mapping categories.

# %%
print(b)

b['Name'].replace('Alice','Darshil',inplace=True)
b['Score'].replace(88,20,inplace=True)
print(b)
# Out:
#       Name  Age  Score
# 0  Darshil   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
#       Name  Age  Score
# 0  Darshil   25     20
# 1      Bob   30     92
# 2  Charlie   35     79
# 3    David   40     85
# 4     Emma   22     95
# /tmp/ipykernel_5760/1430175496.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Name'].replace('Alice','Darshil',inplace=True)
# /tmp/ipykernel_5760/1430175496.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   b['Score'].replace(88,20,inplace=True)

# %% [markdown]
# ## Dropping Rows & Columns (`drop`)
# - `drop(labels, axis=0)` → drop rows by index labels.
# - `drop(labels, axis=1)` → drop columns by name.
# - Use `inplace=True` if you want to modify the DataFrame directly.

# %%
print(b)

#Remove row.
# b.drop(index=2,axis=0,inplace=True)

#Remove column
# b.drop('Score',axis=1,inplace=True)
print(b)
# Out:
#       Name  Age
# 0  Darshil   25
# 1      Bob   30
# 3    David   40
# 4     Emma   22
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_5760/1031471773.py in <cell line: 0>()
#       5
#       6 #Remove column
# ----> 7 b.drop('Score',axis=1,inplace=True)
#       8 print(b)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Score'] not found in axis"

# %% [markdown]
# ## Detecting & Removing Duplicates
# - `duplicated()` → returns a Boolean Series marking duplicate rows.
# - `drop_duplicates()` → remove duplicate rows.
# - You can specify `subset` (columns) and `keep` ('first', 'last', or False).

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "Alice", "Bob", "David"],
    "Age": [25, 30, 35, 25, 30, 40],
    "Score": [88, 92, 79, 88, 92, 85]
}

df = pd.DataFrame(data)

df.duplicated().sum() #Total Duplicated values count

df.drop_duplicates(inplace=True)#exact same ya identical rows toh hi drop

print(df)
# Out:
#       Name  Age  Score
# 0    Alice   25     88
# 1      Bob   30     92
# 2  Charlie   35     79
# 5    David   40     85

# %% [markdown]
# ## Mini Practice
# 1. Create a messy DataFrame with missing values, wrong data types, typos, extra columns, and duplicates.
# 2. Clean it step-by-step using what you learned:
#    - Handle missing values
#    - Change data types
#    - Replace incorrect values
#    - Drop unnecessary rows/columns
#    - Remove duplicates

# %%
import pandas as pd
import numpy as np

# 1. Create a messy DataFrame
data = {
    "Name": ["Alice", "Bob", "Chrlie", "David", "Alice", None],
    "Age": ["25", "30", None, "40", "25", "30"],      # ages stored as strings, with missing value
    "City": ["Delhi", "Mumbai", "Pun", "Bangalore", "Delhi", "Mumbai"],  # typo: "Pun" -> "Pune"
    "Score": [85, None, 78, 88, 85, 91],              # missing value in Score
    "Extra": ["x", "y", "z", "x", "y", "z"]           # extra column we don't really need
}

df = pd.DataFrame(data)

print("Original messy DataFrame:")
print(df)

# 2. Handle missing values
# Fill or drop as needed
print(df.isna())

# Before converting 'Age' to int, fill missing values
# For simplicity, filling with a placeholder like 0, but a more statistical approach (mean/median) might be better
df['Age'] = df['Age'].fillna('0') # Fill None with string '0' first, as age contains strings and None

# Before converting 'Score' to float, fill missing values
df['Score'] = df['Score'].fillna(df['Score'].mean())

# 3. Change data types
# Convert Age to int, Score to float, etc.
df['Score'] = df['Score'].astype(float)
df['Age'] = df['Age'].astype(int)

# 4. Replace incorrect values
# Fix 'Pun' -> 'Pune', maybe unify Name spellings if needed
df['City'] = df['City'].replace('Pun', 'Pune')

# 5. Drop unnecessary rows/columns
# Remove 'Extra' or any row you don't want
df = df.drop('Extra', axis=1)

# 6. Remove duplicates
# Use duplicated() and drop_duplicates()
df = df.drop_duplicates()

# 7. Final clean DataFrame
# Print the cleaned DataFrame and check info()
print("\nCleaned DataFrame:")
print(df)
print("\nDataFrame Info:")
df.info()
# Out:
# Original messy DataFrame:
#      Name   Age       City  Score Extra
# 0   Alice    25      Delhi   85.0     x
# 1     Bob    30     Mumbai    NaN     y
# 2  Chrlie  None        Pun   78.0     z
# 3   David    40  Bangalore   88.0     x
# 4   Alice    25      Delhi   85.0     y
# 5    None    30     Mumbai   91.0     z
#     Name    Age   City  Score  Extra
# 0  False  False  False  False  False
# 1  False  False  False   True  False
# 2  False   True  False  False  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False
# 5   True  False  False  False  False
#
# Cleaned DataFrame:
#      Name  Age       City  Score
# 0   Alice   25      Delhi   85.0
# 1     Bob   30     Mumbai   85.4
# 2  Chrlie    0       Pune   78.0
# 3   David   40  Bangalore   88.0
# 5    None   30     Mumbai   91.0
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Score   5 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 200.0+ bytes

# %% [markdown]
# ---
# ## Summary
# - Learned to handle missing values (`isna`, `dropna`, `fillna`).
# - Converted column data types with `astype`.
# - Cleaned up incorrect entries with `replace`.
# - Removed unwanted rows/columns with `drop`.
# - Detected and removed duplicates.
